# %% [markdown]
# # Question 1

# %% [markdown]
# | Question       | Ans     |
# |------          | ------- |
# |5               | int     |
# |5.0             | float   |
# |5 > 1           | bool    |
# |'5'             | char    |
# |5 * 2           | int     |
# |'5' * 2         | int     |
# |'5' + '2'       | int     |
# |5 / 2           | int     |
# |5 % 2           | int     |
# |{5, 2, 1}       | int arr |
# |5 == 2          | bool    |
# |Pi (the number) | double  |

# %% [markdown]
# # Question 2

# %%
Answer:-a

using System;
class HelloWorld {
  static void Main() {
      
    string str = "Supercalifragilisticexpialidocious";
    Console.WriteLine("Number of Letters: "+str.Length);
  }
}
 

 

Answer:-b

using System;
class HelloWorld {
  static void Main() {
      
    string str = "Supercalifragilisticexpialidocious";
    
    //index of return starting index of given substring if string does not contain it then it return -1
    int charPos = str.IndexOf("ice");
    
    if(charPos == -1)
    {
       Console.WriteLine("String does not contain 'ice' as a substring."); 
    }
    else
    {
        Console.WriteLine("String contain 'ice' as a substring.");
    }
    
  }
}

Anc c



By using System;  
public class
{  
    public static void Main() 
      {          
                    string line = "Write a C# Sharp Program to display the following pattern using the alphabet.";
                    string[] words = line.Split(new[] { " " }, StringSplitOptions.None);
                        string word = "";
                        int ctr = 0;
                        foreach (String s in words)
                        {
                            if (s.Length > ctr)
                            {
                                word = s;
                                ctr = s.Length;
                            }
                        }
                   
                        Console.WriteLine(word);
                    
    }
    
ans d
    
    composers = ['Berlioz', 'Borodin', 'Brian', 'Bartok', 'Bellini', 'Buxtehude', 'Berns
tein']
composers.sort()
print(composers)
# Out:
#   File "C:\Users\Dell\AppData\Local\Temp/ipykernel_50524/2891522780.py", line 3
#     using System;
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Question 3

# %%
static double triangleArea(int a , int b , int c) // no parameter  
{  
    // calculate the value of s
    int s = (a + b + c) / 2;
    // calculate the area using Heron formula
    double area = math.sqrt(s (s - a) (s - b) (s - c)
    // return the area calculated
    return area;
}

# %% [markdown]
# ![SCPS%20-3.jpg](attachment:SCPS%20-3.jpg)

# %% [markdown]
# # Question 4

# %%
By using System;
class OddEven
{
    static void Main() 
    {
        // take the array Size and Declare aray
        Console.Write("Input the number of elements to be stored in the array: ");
        int n = Convert.ToInt42(Console.ReadLine()
        int[] arr = new int[n];
        
        // input the array elements
        Console.WriteLine("Input " + n + " elements in the array");
        for(int i = 0; i < n; i++)
        {
            Console.Write("element - " + i + " : ");
            arr[i] = Convert.ToInt42(Console.ReadLine();
        }
        
        // segregate the odd and even elements
        int[] even = new int[n];
        int[] odd = new int[n];
        
        int evenIndex = 0, oddIndex = 0;
        
        for(int i = 0; i < n; i++)
        {
            if(arr[i] % 2 == 0)
            {
                even[evenIndex] = arr[i];
                evenIndex++;
            }
            else
            {
                odd[oddIndex] = arr[i];
                oddIndex++;
            }
        }
        
        // display the odd and even elements
        Console.WriteLine("The even elements are:");
        for(int i = 0; i < evenIndex; i++)
            Console.Write(even[i] + " ");
        Console.WriteLine("\nThe odd elements are:");
        for(int i = 0; i < oddIndex; i++)
            Console.Write(odd[i] + " ");
    }
}

# %% [markdown]
# ![SCPS%20-%204.jpg](attachment:SCPS%20-%204.jpg)

# %% [markdown]
# # Question 5

# %%
to find that given point lie inside the given rectangle or not.
static bool inside(int x, int y, int x1, int y1, int x2, int y2)
{
if (x > x1 && x < x2 && y > y1 && y < y2)
return true; 

return false;

# %% [markdown]
# ![SCPS%20-%205.jpg](attachment:SCPS%20-%205.jpg)

# %% [markdown]
# # Question 6

# %%
#function pig
def pig(piglatin):
#applying lower() method so that if input cc
#to lower case.applying split() method so th
Completeword = piglatin.lower().split(" ")
# declaring Vowels i.e 'a','e 'i','o', 'u'
Vowels = ['a', 'e', 'i', 'u']
#empty piglatin
piglatin = []
for Word in CompleteWord:
# if Word[0] (i.e first word) of input i
if Word[0] in 'aeiou':
piglatin.append(Word + 'way') #apper
else:
for letter in Word:
if letter in 'aeiou':
piglatin.append(Word[Word.inde
break
#here, piglatin.append(Word[Word.index(1
#can be summarised as an example i.e wor
#piglatin.append(Word[Word.index(letter)
#Word[:Word.index(letter)] is first word
print(" ".join(piglatin)) #join method add a
pig('Enter')
# calling pig function
The output of calling pig('Enter') is :
enterway
Similarly, the Output of calling pig('happy') is:
appyhay
The function will still work if the input contains uppel
the Output of calling pig('HAPPY') is:
appyhay

# %% [markdown]
# # Question 7

# %%
def bldcount (name) :
Try:
With open (name, 'r') as f:
o_count, a_count, b_count, ab_count, co_count = 0, 0, 0, 0, 0
For line in f:
Words = line.strip().upper().split(',')
Blood = words [1].strip ()
If blood == 'O':
o_count += 1
If blood == 'A':
a_count += 1
If blood == 'B':
b_count += 1
If blood == 'AB':
ab_count += 1
If blood == '00':
oo_count += 1
If a count == 0:
Print ("There are no patients of blood type A.")
elif a count == 1:
rint ("There is one patient of blood type ")
Else:
Print ("There are [ patients with blood type
A.".format(a_count))
If b count == 0:
Print ("There is no patients of blood type B.")
elif b count == 1:
Print ("There is a patient of blood type B.")
Else:
Print ("There is a patients with blood type
B.".Format(b_count))
If ab_count == 0:
Print ("There are no patients of blood type AB.")
elif ab count == 1:
Print ("There is a patient of blood type AB.")
Else:
Print ("There is patient with blood type
AB.". format (ab_count))
If o count == 0:
Print ("There are no patients of blood type 0.")
elif o_count == 1:
Print ("There is one patient of blood type 0.")
Else:
Print ("There are {) patients with blood type
0.".Format (o_count))
If oo_count == 0:
Print ("There are no patients of blood type oo.")
elif oo_count == 1:
Print ("There is one patient of blood type 00.")
Else:
Print ("There are { } patients with blood type
00.". format (oo_count))
Except FileNotFoundError:
Print (name + "does not exists!")
bldcount('bloodtype.txt')

# %% [markdown]
# # Question 8

# %%
urconv(a,b):
    ans=0
    l=['AUD','CHF','CNY','DKK','EUR','GBP','HKD','INR','JPY','MXN','MYR','NOK','NZD','PHP','SEK','SGD','THB']
    l1=[1.0345157,1.0237414,0.1550176,0.1651442,1.2296544,1.5550989,0.1270207,0.0177643,0.01241401,0.0751848,0.3145411,0.1677063,0.8003591,0.0233234,0.148269,0.788871,0.0313789]
    for i in range(len(l)):
        if(l[i]==a):
            ans=b*l1[i]
            break
    return ans
print(curconv('JPY",100))

# %% [markdown]
# # Question 9

# %%
Trying to add incompatible variables, as in adding 6+  'a' can cause a Number Format Exception exception. 

Ans.
1 Referring to 12th item of the list that have only 10 items can cause ArrayIndex Out Of Bounds Exception because the index of accessing the item does not exist 

2 Using value that is out of range for a functions input, such as calling math.sqrt(-1.0) 

Will cause Arithmetic Exception because a negative number cannot have square root and the message should be not take square root of negative number 

Point to point explanation


3 Using an undeclared variable such as print(x) when x has not been defined will cause compile time error, all variables must be declared before being used. 

4 Trying to open a file that does not exist such as mistyping the file name or looking in the wrong directory will cause FileNotFoundException. This Exception is thrown when a file is typed wrongly or does not open, or when the file is in a different directory.

# %% [markdown]
# # Question 10

# %%
Method takes string as input and return the dictionary corrosponding to different
# charcter of alphabet and their frequencies. 

import string
from collections import OrderedDict
def frequencies(str1):
dict1=dict(OrderedDict(zip(string.ascii_lowercase,[0]*26)))
  
# iterate string to store the charcter's frequencies in dictionary.
for i in range(0,len(str1)):
if str1[i]=='a' or str1[i]=='A':
dict1['a']+=1
  
elif str1[i]=='b' or str1[i]=='B':
dict1['b']+=1
  
elif str1[i]=='c' or str1[i]=='c':
dict1['c']+=1
  
elif str1[i]=='d' or str1[i]=='D':
dict1['d']+=1
  
elif str1[i]=='e' or str1[i]=='E':
dict1['e']+=1
  
elif str1[i]=='f' or str1[i]=='F':
dict1['f']+=1
  
elif str1[i]=='g' or str1[i]=='G':
dict1['g']+=1
  
elif str1[i]=='h' or str1[i]=='H':
dict1['h']+=1
  
elif str1[i]=='i' or str1[i]=='I':
dict1['i']+=1
  
elif str1[i]=='j' or str1[i]=='J':
dict1['j']+=1
  
elif str1[i]=='k' or str1[i]=='K':
dict1['k']+=1
  
elif str1[i]=='l' or str1[i]=='L':
dict1['l']+=1
  
elif str1[i]=='m' or str1[i]=='M':
dict1['m']+=1
  
elif str1[i]=='n' or str1[i]=='N':
dict1['n']+=1
  
elif str1[i]=='o' or str1[i]=='O':
dict1['o']+=1
  
elif str1[i]=='p' or str1[i]=='P':
dict1['p']+=1
  
elif str1[i]=='q' or str1[i]=='Q':
dict1['q']+=1
  
elif str1[i]=='r' or str1[i]=='R':
dict1['r']+=1
  
elif str1[i]=='s' or str1[i]=='S':
dict1['s']+=1
  
elif str1[i]=='t' or str1[i]=='T':
dict1['t']+=1
  
elif str1[i]=='u' or str1[i]=='U':
dict1['u']+=1
  
elif str1[i]=='v' or str1[i]=='V':
dict1['v']+=1
  
elif str1[i]=='w' or str1[i]=='W':
dict1['w']+=1
  
elif str1[i]=='x' or str1[i]=='X':
dict1['x']+=1
  
elif str1[i]=='y' or str1[i]=='Y':
dict1['y']+=1
  
elif str1[i]=='z' or str1[i]=='Z':
dict1['z']+=1
  
# Return dictionary
return dict1 

def main():
str1=input("Enter String : ")
dict1=frequencies(str1)
print("Resultant Dictionary : ")
print(dict1) 

if _name=="main_":
main()
